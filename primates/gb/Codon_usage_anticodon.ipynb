# %% [markdown]
# # Codon Usage and tRNA Anticodon
#
# Using a list of genbank files as input, this script:
#
# - [x] Extracts all its CDS's
# - [x] Calculates codon usage
#
# ---
#
# - [x] Converts each sequence to fasta (or only the concatenated tRNAs)
# - [x] Uses the trnascan-SE to identify the anticodon
#
# ---
#
# Generates an excel spreadsheet, containing the following fields:
#
# - [x] Species
#
# - [x] Translation table
#
# - [x] Aminoacid (Three-letter code)
#
# - [x] Codon for that aminoacid
#
# - [ ] Has anticodon in mito tRNAs? YES or EMPTY VALUE
#
# - [x] Number of occurrences of that codon in the genes
#
# - [x] \1000 - (number_of_codon_occurences / total number of aa - including start_stop_codons) * 1000
#
# - [x] Fraction: codon occurences / sum of all codon occurences for that aa

# %% [markdown]
# Let's import everything we need:

# %%
from Bio import SeqIO
import pandas
from Bio.Seq import Seq
from Bio.Alphabet import generic_dna
from Bio.Data import CodonTable
from Bio.SeqUtils import seq3
import subprocess, os

# %% [markdown]
# In order for this script to work, you have to execute it from within the directory with the genbank files or change the working directory using  **os.chdir("path/to/directory/")**

# %% [markdown]
# First, we need to add all gb files **(no .gbk allowed!)** to a list:

# %%
genbank = !ls *gb
genbank
# Out:
# ['Allenopithecus_nigroviridis_NC_023965.1.gb',
#  'Allocebus_trichotis_NC_035631.1.gb',
#  'Allochrocebus_lhoesti_NC_023962.1.gb',
#  'Alouatta_caraya_NC_021938.1.gb',
#  'Alouatta_seniculus_NC_027825.1.gb',
#  'Aotus_azarai_NC_021939.1.gb',
#  'Aotus_azarai_azarai_NC_018115.1.gb',
#  'Aotus_lemurinus_NC_019799.1.gb',
#  'Aotus_nancymaae_NC_018116.1.gb',
#  'Ateles_belzebuth_NC_019800.1.gb',
#  'Avahi_laniger_NC_021940.1.gb',
#  'Cacajao_calvus_NC_021967.1.gb',
#  'Callimico_goeldii_NC_024628.1.gb',
#  'Callithrix_geoffroyi_NC_021941.1.gb',
#  'Callithrix_jacchus_NC_025586.1.gb',
#  'Callithrix_kuhlii_NC_027658.1.gb',
#  'Callithrix_penicillata_NC_030788.1.gb',
#  'Callithrix_pygmaea_NC_021942.1.gb',
#  'Carlito_syrichta_NC_012774.1.gb',
#  'Cebus_albifrons_NC_002763.1.gb',
#  'Cephalopachus_bancanus_NC_002811.1.gb',
#  'Cercocebus_atys_NC_028592.1.gb',
#  'Cercocebus_chrysogaster_NC_021943.1.gb',
#  'Cercocebus_torquatus_NC_023964.1.gb',
#  'Cercopithecus_albogularis_NC_021944.1.gb',
#  'Cercopithecus_diana_NC_023963.1.gb',
#  'Cercopithecus_mitis_NC_023961.1.gb',
#  'Cheirogaleus_crossleyi_NC_035604.1.gb',
#  'Cheirogaleus_major_NC_035655.1.gb',
#  'Cheirogaleus_medius_NC_021945.1.gb',
#  'Cheirogaleus_sibreei_NC_035605.1.gb',
#  'Cheracebus_lugens_NC_024630.1.gb',
#  'Chiropotes_albinasus_NC_021946.1.gb',
#  'Chiropotes_israelita_NC_024629.1.gb',
#  'Chlorocebus_aethiops_NC_007009.1.gb',
#  'Chlorocebus_aethiops_x_Chlorocebus_pygerythrus_NC_034276.1.gb',
#  'Chlorocebus_cynosuros_NC_024933.1.gb',
#  'Chlorocebus_djamdjamensis_NC_034277.1.gb',
#  'Chlorocebus_pygerythrus_NC_009747.1.gb',
#  'Chlorocebus_sabaeus_NC_008066.1.gb',
#  'Chlorocebus_tantalus_NC_009748.1.gb',
#  'Colobus_guereza_NC_006901.1.gb',
#  'Daubentonia_madagascariensis_NC_010299.1.gb',
#  'Erythrocebus_patas_NC_021947.1.gb',
#  'Eulemur_fulvus_fulvus_NC_012766.1.gb',
#  'Eulemur_fulvus_mayottensis_NC_012769.1.gb',
#  'Eulemur_macaco_macaco_NC_012771.1.gb',
#  'Eulemur_mongoz_NC_010300.1.gb',
#  'Eulemur_rubriventer_NC_026098.1.gb',
#  'Eulemur_rufus_NC_021948.1.gb',
#  'Galago_moholi_NC_021949.1.gb',
#  'Galago_senegalensis_NC_012761.1.gb',
#  'Gorilla_beringei_NC_037853.1.gb',
#  'Gorilla_gorilla_NC_001645.1.gb',
#  'Gorilla_gorilla_gorilla_NC_011120.1.gb',
#  'Hapalemur_griseus_NC_021950.1.gb',
#  'Homo_heidelbergensis_NC_023100.1.gb',
#  'Homo_sapiens_NC_012920.1.gb',
#  'Homo_sapiens_neanderthalensis_NC_011137.1.gb',
#  'Homo_sapiens_subsp._Denisova_NC_013993.1.gb',
#  'Hoolock_hoolock_NC_033885.1.gb',
#  'Hoolock_leuconedys_NC_033882.1.gb',
#  'Hoolock_leuconedys_x_Hoolock_tianxing_NC_033883.1.gb',
#  'Hoolock_tianxing_NC_033884.1.gb',
#  'Hylobates_agilis_NC_014042.1.gb',
#  'Hylobates_lar_NC_002082.1.gb',
#  'Hylobates_pileatus_NC_014045.1.gb',
#  'Indri_indri_NC_026095.1.gb',
#  'Lagothrix_lagotricha_NC_021951.1.gb',
#  'Lemur_catta_NC_004025.1.gb',
#  'Leontopithecus_chrysopygus_NC_037878.1.gb',
#  'Leontopithecus_rosalia_NC_021952.1.gb',
#  'Lepilemur_aeeclis_NC_034730.1.gb',
#  'Lepilemur_ahmansonorum_NC_034733.1.gb',
#  'Lepilemur_ankaranensis_NC_034717.1.gb',
#  'Lepilemur_betsileo_NC_034726.1.gb',
#  'Lepilemur_dorsalis_NC_034721.1.gb',
#  'Lepilemur_edwardsi_NC_034720.1.gb',
#  'Lepilemur_fleuretae_NC_034718.1.gb',
#  'Lepilemur_grewcockorum_NC_034729.1.gb',
#  'Lepilemur_hollandorum_NC_034738.1.gb',
#  'Lepilemur_hubbardorum_NC_014453.1.gb',
#  'Lepilemur_jamesorum_NC_034736.1.gb',
#  'Lepilemur_leucopus_NC_034719.1.gb',
#  'Lepilemur_microdon_NC_034739.1.gb',
#  'Lepilemur_milanoii_NC_034725.1.gb',
#  'Lepilemur_mittermeieri_NC_034728.1.gb',
#  'Lepilemur_otto_NC_034724.1.gb',
#  'Lepilemur_petteri_NC_034723.1.gb',
#  'Lepilemur_randrianasoloi_NC_034722.1.gb',
#  'Lepilemur_ruficaudatus_NC_021953.1.gb',
#  'Lepilemur_sahamalazensis_NC_034734.1.gb',
#  'Lepilemur_scottorum_NC_034737.1.gb',
#  'Lepilemur_seali_NC_034731.1.gb',
#  'Lepilemur_septentrionalis_NC_034727.1.gb',
#  'Lepilemur_tymerlachsoni_NC_034735.1.gb',
#  'Lepilemur_wrightae_NC_034732.1.gb',
#  'Lophocebus_aterrimus_NC_021954.1.gb',
#  'Loris_lydekkerianus_NC_021955.1.gb',
#  'Loris_tardigradus_NC_012763.1.gb',
#  'Macaca_arctoides_NC_025201.1.gb',
#  'Macaca_assamensis_NC_023795.1.gb',
#  'Macaca_cyclopis_NC_027449.1.gb',
#  'Macaca_fascicularis_NC_012670.1.gb',
#  'Macaca_fuscata_NC_025513.1.gb',
#  'Macaca_leonina_NC_027604.1.gb',
#  'Macaca_leucogenys_NC_031156.1.gb',
#  'Macaca_mulatta_NC_005943.1.gb',
#  'Macaca_mulatta_vestita_NC_037466.1.gb',
#  'Macaca_nemestrina_NC_026976.1.gb',
#  'Macaca_nigra_NC_026120.1.gb',
#  'Macaca_radiata_NC_036508.1.gb',
#  'Macaca_silenus_NC_025221.1.gb',
#  'Macaca_sinica_NC_037437.1.gb',
#  'Macaca_sylvanus_NC_002764.1.gb',
#  'Macaca_thibetana_NC_011519.1.gb',
#  'Macaca_tonkeana_NC_025222.1.gb',
#  'Mandrillus_leucophaeus_NC_028442.1.gb',
#  'Mandrillus_sphinx_NC_021956.1.gb',
#  'Megaladapis_edwardsi_NC_026088.1.gb',
#  'Microcebus_arnholdi_NC_035554.1.gb',
#  'Microcebus_berthae_NC_035629.1.gb',
#  'Microcebus_bongolavensis_NC_035559.1.gb',
#  'Microcebus_danfossi_NC_035600.1.gb',
#  'Microcebus_griseorufus_NC_035558.1.gb',
#  'Microcebus_jollyae_NC_035564.1.gb',
#  'Microcebus_lehilahytsara_NC_035602.1.gb',
#  'Microcebus_mamiratra_NC_035601.1.gb',
#  'Microcebus_margotmarshae_NC_035603.1.gb',
#  'Microcebus_mittermeieri_NC_035563.1.gb',
#  'Microcebus_murinus_NC_028718.1.gb',
#  'Microcebus_myoxinus_NC_035557.1.gb',
#  'Microcebus_ravelobensis_NC_035556.1.gb',
#  'Microcebus_rufus_NC_035562.1.gb',
#  'Microcebus_sambiranensis_NC_035561.1.gb',
#  'Microcebus_simmonsi_NC_035630.1.gb',
#  'Microcebus_tanosi_NC_035555.1.gb',
#  'Microcebus_tavaratra_NC_035560.1.gb',
#  'Mirza_coquereli_NC_035656.1.gb',
#  'Mirza_zaza_NC_035606.1.gb',
#  'Nasalis_larvatus_NC_008216.1.gb',
#  'Nomascus_gabriellae_NC_018753.1.gb',
#  'Nomascus_leucogenys_NC_021957.1.gb',
#  'Nomascus_siki_NC_014051.1.gb',
#  'Nycticebus_bengalensis_NC_021958.1.gb',
#  'Nycticebus_coucang_NC_002765.1.gb',
#  'Nycticebus_coucang_insularis_NC_040292.1.gb',
#  'Nycticebus_pygmaeus_NC_033381.1.gb',
#  'Otolemur_crassicaudatus_NC_012762.1.gb',
#  'Palaeopropithecus_ingens_NC_026090.1.gb',
#  'Pan_paniscus_NC_001644.1.gb',
#  'Pan_troglodytes_NC_001643.1.gb',
#  'Papio_anubis_NC_020006.2.gb',
#  'Papio_cynocephalus_NC_020007.2.gb',
#  'Papio_hamadryas_NC_001992.1.gb',
#  'Papio_kindae_NC_020008.2.gb',
#  'Papio_papio_NC_020009.2.gb',
#  'Papio_ursinus_NC_020010.2.gb',
#  'Perodicticus_potto_NC_012764.1.gb',
#  'Phaner_electromontis_NC_035607.1.gb',
#  'Phaner_pallescens_NC_035608.1.gb',
#  'Phaner_parienti_NC_035609.1.gb',
#  'Piliocolobus_badius_NC_008219.1.gb',
#  'Plecturocebus_cupreus_NC_021965.1.gb',
#  'Plecturocebus_donacophilus_NC_019801.1.gb',
#  'Pongo_abelii_NC_002083.1.gb',
#  'Pongo_pygmaeus_NC_001646.1.gb',
#  'Presbytis_melalophos_NC_008217.1.gb',
#  'Procolobus_verus_NC_020666.1.gb',
#  'Prolemur_simus_NC_021959.1.gb',
#  'Propithecus_coquereli_NC_011053.1.gb',
#  'Propithecus_diadema_NC_026084.1.gb',
#  'Propithecus_edwardsi_NC_026086.1.gb',
#  'Propithecus_tattersalli_NC_027740.1.gb',
#  'Propithecus_verreauxi_NC_028210.1.gb',
#  'Pygathrix_cinerea_1_RL-2012_NC_018062.1.gb',
#  'Pygathrix_cinerea_2_RL-2012_NC_018063.1.gb',
#  'Pygathrix_nemaeus_NC_008220.1.gb',
#  'Pygathrix_nigripes_NC_018061.1.gb',
#  'Rhinopithecus_avunculus_NC_015485.1.gb',
#  'Rhinopithecus_bieti_1_RL-2012_NC_018058.1.gb',
#  'Rhinopithecus_bieti_2_RL-2012_NC_018060.1.gb',
#  'Rhinopithecus_bieti_NC_015486.1.gb',
#  'Rhinopithecus_brelichi_NC_018057.1.gb',
#  'Rhinopithecus_roxellana_NC_008218.1.gb',
#  'Rhinopithecus_strykeri_NC_018059.1.gb',
#  'Saguinus_oedipus_NC_021960.1.gb',
#  'Saimiri_boliviensis_NC_021966.1.gb',
#  'Saimiri_boliviensis_boliviensis_NC_018096.1.gb',
#  'Saimiri_oerstedii_citrinellus_NC_023211.1.gb',
#  'Saimiri_sciureus_NC_012775.1.gb',
#  'Sapajus_xanthosternos_NC_021961.1.gb',
#  'Semnopithecus_entellus_NC_008215.1.gb',
#  'Simias_concolor_NC_020667.1.gb',
#  'Symphalangus_syndactylus_NC_014047.1.gb',
#  'Tarsius_dentatus_NC_024052.1.gb',
#  'Tarsius_lariang_NC_024051.1.gb',
#  'Tarsius_wallacei_NC_024053.1.gb',
#  'Theropithecus_gelada_NC_019802.1.gb',
#  'Trachypithecus_cristatus_NC_023971.1.gb',
#  'Trachypithecus_francoisi_NC_023970.1.gb',
#  'Trachypithecus_germaini_NC_019580.1.gb',
#  'Trachypithecus_hatinhensis_NC_019579.1.gb',
#  'Trachypithecus_johnii_NC_019583.1.gb',
#  'Trachypithecus_obscurus_NC_006900.1.gb',
#  'Trachypithecus_pileatus_NC_024529.1.gb',
#  'Trachypithecus_poliocephalus_NC_034795.1.gb',
#  'Trachypithecus_shortridgei_NC_019581.1.gb',
#  'Trachypithecus_vetulus_NC_019582.1.gb',
#  'Varecia_variegata_NC_026085.1.gb',
#  'Varecia_variegata_variegata_NC_012773.1.gb']

# %%
genbank[0]
# Out:
# 'Allenopithecus_nigroviridis_NC_023965.1.gb'

# %% [markdown]
# # trnascan
# There are files for the different genetic tables in /home/gabriel/bioinfo/anaconda3/lib/tRNAscan-SE/gcode/gcode.vertmito.
# Maybe looking at this will give me some ideas on how to run the trnascan for other tables.

# %%
def genbank_to_fasta(genbank):
    record = SeqIO.read(genbank, "genbank")
    species = record.annotations.get("organism").replace(" ", "_")
    seq = record.seq
    fasta = ">{}\n{}".format(species, seq)
    return(fasta)

# %%
def run_trnascan(genbank):
    fasta = genbank_to_fasta(genbank)
    with open("tempfile", "w+") as tempfile:
        tempfile.write(fasta)
        trnascan = subprocess.Popen(["tRNAscan-SE", "-M", "mammal", "tempfile"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        trnascan.wait()
        output, error = trnascan.communicate()
        os.remove("tempfile")
        return(output.decode().split("\n"))

# %%
def trnascan_se_anticodon_parser(trnascan_output, species):
    anticodon_dict = dict()
    for i in trnascan_output:
         if i.startswith(species):
                i = i.split("\t")
                aminoacid = i[4].strip()
                anticodon = i[5].strip()
                if aminoacid not in anticodon_dict:
                    anticodon_dict[aminoacid] = list()
                anticodon_dict.get(aminoacid).append(anticodon)
                
    return(anticodon_dict)

# %% [markdown]
# ---
# We also have to calculate codon usage for all CDSs. In order to do so, we first need to extract all CDS from the genbank file, make sure that all sequences are multiple of 3 (or otherwise adding "A" residues from poly-A tail to complete the codon) and concatenate the CDS's.

# %%
def extract_CDS(genbank):
    CDS_list = list()
    for record in SeqIO.parse(genbank, "genbank"):
        accession = record.id
        species_name = record.annotations.get("organism").replace(" ", "_")
        for FEATURE in record.features:
            if FEATURE.type == "CDS":
                gene = FEATURE.qualifiers.get("gene")[0]
                sequence = FEATURE.location.extract(record).seq
                CDS_list.append([accession, species_name, gene, sequence])
    return(CDS_list)

# %%
def fix_truncated(coding_list):
    not_trunc_cds_list = list()
    for i in coding_list:
        truncated_nucs = len(i[3]) % 3
        if truncated_nucs:
            missing_nucs = 3 - truncated_nucs
            #REWRITE THIS IN ORDER TO JUST ADD THE RESIDUES FROM THE POLY-A TAIL - DONE
            #print("Truncated stop codon for gene {}".format(i[2]))
            #print("Before:{} truncated_nucs".format(len(i[3]) % 3))
            #print("Before: {}".format(i[3]))
            i[3] = i[3] + (missing_nucs * 'A')
            #print()
            #print("After: {}".format(i[3]))
            #print("After:{} truncated_nucs".format(len(i[3]) % 3))
            not_trunc_cds_list.append(i)
        else:
            not_trunc_cds_list.append(i)
    return(not_trunc_cds_list)

# %% [markdown]
# # NEXT STEP:
#
# Take a look at the "CAI.py" file and use it as a reference to write a function that counts codons for any genetic code.

# %% [markdown]
# Adapted from CAI.py:

# %%
#from itertools import chain
#from Bio.Data import CodonTable
#from collections import Counter
#from Bio.SeqUtils import seq3

# get rid of Biopython warning
#import warnings
#from Bio import BiopythonWarning

#warnings.simplefilter("ignore", BiopythonWarning)


def set_ncbi_genetic_codes():


    ncbi_genetic_codes = {}
    for table, codes in CodonTable.unambiguous_dna_by_id.items():
        
        # invert the genetic code dictionary to map each amino acid to its codons
        # create dictionary of synonymous codons;
        # Example: {'Phe': ['TTT', 'TTC'], ..., 'End': ['TAA', 'TAG', 'TGA']}
        codons_for_amino_acid = {}
        for codon, amino_acid in codes.forward_table.items():
            amino_acid = seq3(amino_acid)
            codons_for_amino_acid[amino_acid] = codons_for_amino_acid.get(amino_acid, [])
            codons_for_amino_acid[amino_acid].append(codon)
        #Adding the stop codons
        codons_for_amino_acid["End"] = CodonTable.unambiguous_dna_by_id[table].stop_codons
        
        #create dictionary of synonymous codons for each genetic table;
        ncbi_genetic_codes[table] = codons_for_amino_acid
        
    return(ncbi_genetic_codes)

#codon_tables = set_ncbi_genetic_codes()

# %%
#print(codon_tables)

# %% [markdown]
# As we can see, all tables have exactly 64 codons, and 20 aminoacids (20 + stop) as expected:

# %%
'''for table in codon_tables.keys():
    codons = 0
    for aa in codon_tables[table]:
        codons += len(codon_tables[table][aa])
    print("Table number: {} \t Number of codons: {} \t Aminoacids: {}".format\
          (table, codons , len(codon_tables[table].keys())))'''
# Out:
# 'for table in codon_tables.keys():\n    codons = 0\n    for aa in codon_tables[table]:\n        codons += len(codon_tables[table][aa])\n    print("Table number: {} \t Number of codons: {} \t Aminoacids: {}".format          (table, codons , len(codon_tables[table].keys())))'

# %%
def count_codons(sequence):
    from itertools import product
    
    #create dictionary with each codon for counting (list comprehension inside dictionary comprehension)
    codon_count_dict = {codon: 0 for codon in 
                  [''.join(i) for i in product("ATCG", repeat=3)]}
    
    if len(sequence) % 3 != 0:
        raise ValueError("Input sequence not divisible by three")
    for n, i in enumerate(range(0, len(sequence), 3), 1):
        codon = str(sequence[i:i+3].upper())
        if codon not in codon_count_dict.keys():
            raise ValueError("This sequence probably has ambiguous IUPAC characters. " 
                             "Please submit sequences containing only A, T, G or C.")
        codon_count_dict[codon] += 1
        
    return(codon_count_dict)

#print(count_codons(concat))

#codon_count = count_codons(concat)

# %% [markdown]
# # NEXT STEP:
# Calculate all metrics associated with codon usage AND map it to its corresponding aminoacids, species, etc.
# Accomodate this data into a dataframe and plot it into an excel file.

# %%
def per_thousand(codon_count_dict):
    total_codon_number = sum(codon_count_dict.values())
    per_thousand = {codon: round((count/total_codon_number)*1000, 2) 
                    for codon, count in codon_count_dict.items()}
    return(per_thousand)    

#per_thousand = per_thousand(codon_count)
#print(per_thousand)

# %%
def identify_genetic_code(genbank):
    record = SeqIO.read(genbank, "genbank")
    genetic_code = set()
    for i in record.features:
        if i.type == "CDS":
            genetic_code.add(i.qualifiers.get("transl_table")[0])
    if len(genetic_code) != 1:
        raise ValueError("The {} file has more than one genetic code for its CDS's: {} " 
                             "Please correct that before submiting".format(genbank, genetic_code))
    return(int(list(genetic_code)[0]))
    
#genetic_code = identify_genetic_code(genbank[0])

# %%
#print(codon_count)

# %%
def fraction(codon_count_dict, transl_table):
    fraction = dict()
    for codon_list in transl_table.values():
        codon_occurrences_per_aa = 0
        for codon in codon_list:
            codon_occurrences_per_aa += codon_count_dict[codon]
        for codon in codon_list:
            fraction[codon] = round(codon_count_dict[codon]/codon_occurrences_per_aa, 2)
    return(fraction)

#fraction = fraction(codon_count, codon_tables[genetic_code])

# %%
def trnascan_se_parser(trnascan_output, sequence_name):
    aminoacid = list()
    anticodon = list()
    for i in trnascan_output:
         if i.startswith(sequence_name):
                i = i.split("\t")
                aminoacid.append(i[4].strip())
                anticodon.append(i[5].strip())
    trnascan_dict = {sequence_name: {i[0]: i[1] for i in zip(aminoacid, anticodon)}}
    return(trnascan_dict)
        

#trna_scan_parse = trnascan_se_parser(trnascan_output, species)

# %%
#print(trna_scan_parse)

# %% [markdown]
# # NEXT:
# Create main function and put all data into a dataframe.
# **TIP:** In the main function, put the codon usage functions first, then the anticodon.
# Structure chosen for the dataframe: list of dictionaries.

# %%
#template:

'''excel_dict = [
    {'species': species_name, 'transl_table': translat_table,
     'aminoacid': Three-letter aa, "Has anticodon in mito?": Yes or no,
    'Number of codon occurences': number of codons, '/1000': per_thousand,
    'Fraction': fraction}
]'''
# Out:
# 'excel_dict = [\n    {\'species\': species_name, \'transl_table\': translat_table,\n     \'aminoacid\': Three-letter aa, "Has anticodon in mito?": Yes or no,\n    \'Number of codon occurences\': number of codons, \'/1000\': per_thousand,\n    \'Fraction\': fraction}\n]'

# %% [markdown]
# - [x] Species
#
# - [x] Translation table
#
# - [x] Aminoacid (Three-letter code)
#
# - [x] Codon for that aminoacid
#
# - [ ] Has anticodon in mito tRNAs? YES or EMPTY VALUE
#
# - [x] Number of occurrences of that codon in the genes
#
# - [x] \1000 - (number_of_codon_occurences / total number of aa - including start_stop_codons) * 1000
#
# - [x] Fraction: codon occurences / sum of all codon occurences for that aa

# %%
def concatenate_CDS(not_trunc):
    concat = ''
    for i in not_trunc:
        concat += i[3]
    return concat

def species_name(not_trunc):
    species = set()
    for i in not_trunc:
        species.add(i[1])
    if len(species) == 1:
        return list(species)[0]
    else:
        raise ValueError("More than one organism for a single genbank file?")

# %%
def invert_codon_table(codon_table):
    new_codon_table = dict()
    for key in codon_table.keys():
        #print(key)
        for codon in codon_table.get(key):
            new_codon_table[codon] = key
            
    return(new_codon_table)

# %%
def has_anticodon(codon, aa_3letter, anticodon_dict):
    #print(aa_3letter)
    if aa_3letter in anticodon_dict.keys():
        for value in anticodon_dict.get(aa_3letter):
            anticodon = Seq(value, generic_dna)
            if codon == str(anticodon.reverse_complement()):
                return(value)
    return(None)

# %%
def dataframe_parser(species, genetic_code, inverse_codon_table, 
                     codon_count_dict, per_thousand_dict, fraction_dict, 
                     anticodon_dict):
    fields = ['Species', 'Translation Table', 'Aminoacid', 'Codon', 'Anticodon', 
                  'Number of Codon Occurences', '/1000', 'Fraction']
    dataframe_dict = {k : list() for k in fields}
    for codon, fraction in fraction_dict.items():
        dataframe_dict.get('Species').append(species)
        dataframe_dict.get('Translation Table').append(genetic_code)
        aa_3letter = inverse_codon_table.get(codon)
        dataframe_dict.get('Aminoacid').append(aa_3letter)
        dataframe_dict.get('Codon').append(codon)
        dataframe_dict.get('Anticodon').append(has_anticodon(codon, aa_3letter, anticodon_dict))
        dataframe_dict.get('Number of Codon Occurences').append(codon_count_dict.get(codon))
        dataframe_dict.get('/1000').append(per_thousand_dict.get(codon))
        dataframe_dict.get('Fraction').append(fraction)
    return(dataframe_dict)

# %%
def create_dataframe(parsed_data):
    codon_usage = pandas.DataFrame(parsed_data)
    return(codon_usage)

# %%
def concat_dataframes(dataframe_data):
    dataframes = []
    for i in dataframe_data.keys():
        dataframes.append(dataframe_data.get(i))
    final_dataframe = pandas.concat(dataframes)
    return(final_dataframe)

# %%
def export_dataframe_to_excel(final_dataframe):
    final_dataframe.to_excel("Codon_usage.xlsx", index=False, sheet_name="codon_usage")

# %%
def main_func(genbank_list):
    codon_tables = set_ncbi_genetic_codes()
    dataframe_data = dict()
    for index, genbank in enumerate(genbank_list, 1):
        print("Running analysis for {}".format(genbank))
        try:
            not_trunc = fix_truncated(extract_CDS(genbank))
        
            cds_concat = concatenate_CDS(not_trunc)
        
            species = species_name(not_trunc)
        
            codon_count_dict = count_codons(cds_concat)
        
            per_thousand_dict = per_thousand(codon_count_dict)
        
            genetic_code = identify_genetic_code(genbank)
                
            fraction_dict = fraction(codon_count_dict, codon_tables[genetic_code])
        
            trnascan_output = run_trnascan(genbank)
        
            anticodon_dict = trnascan_se_anticodon_parser(trnascan_output, species)
        
            inverse_codon_table = invert_codon_table(codon_tables[genetic_code])
        
            parsed_data = dataframe_parser(species, genetic_code, inverse_codon_table, 
                                           codon_count_dict, per_thousand_dict, fraction_dict, 
                                           anticodon_dict)
        except:
            print("{} analysis failed".format(genbank))
            continue
        
        dataframe_data[index] = create_dataframe(parsed_data)
        
    final_dataframe = concat_dataframes(dataframe_data)
    print(final_dataframe)
    
    export_dataframe_to_excel(final_dataframe)
        
        #print(anticodon_dict.keys())
        #print(len(anticodon_dict.keys()))
        #print(set(inverse_codon_table.values()))
        #print(len(set(inverse_codon_table.values())))
        #print(species, type(species))
        #print(not_trunc)
        #print(cds_concat)
        #print("per_thousand_dict:\n{}".format(per_thousand_dict))
        #print("codon_count_dict:\n{}".format(codon_count_dict))
        #print("genetic_code {}:\n{}".format(genetic_code, codon_tables[genetic_code]))    
        #print("fraction_dict:\n{}".format(fraction_dict))
'''        fields = ['species', 'transl_table', 'aminoacid', "Anticodon", 
                  'Number of codon occurences', '/1000', 'Fraction']
        excel_output_dict = {k : list() for k in fields}
'''
main_func(genbank)
# Out:
# Running analysis for Allenopithecus_nigroviridis_NC_023965.1.gb
# Running analysis for Allocebus_trichotis_NC_035631.1.gb
# Running analysis for Allochrocebus_lhoesti_NC_023962.1.gb
# Running analysis for Alouatta_caraya_NC_021938.1.gb
# Running analysis for Alouatta_seniculus_NC_027825.1.gb
# Running analysis for Aotus_azarai_NC_021939.1.gb
# Running analysis for Aotus_azarai_azarai_NC_018115.1.gb
# Running analysis for Aotus_lemurinus_NC_019799.1.gb
# Running analysis for Aotus_nancymaae_NC_018116.1.gb
# Aotus_nancymaae_NC_018116.1.gb analysis failed
# Running analysis for Ateles_belzebuth_NC_019800.1.gb
# Running analysis for Avahi_laniger_NC_021940.1.gb
# Running analysis for Cacajao_calvus_NC_021967.1.gb
# Running analysis for Callimico_goeldii_NC_024628.1.gb
# Running analysis for Callithrix_geoffroyi_NC_021941.1.gb
# Running analysis for Callithrix_jacchus_NC_025586.1.gb
# Running analysis for Callithrix_kuhlii_NC_027658.1.gb
# Running analysis for Callithrix_penicillata_NC_030788.1.gb
# Running analysis for Callithrix_pygmaea_NC_021942.1.gb
# Running analysis for Carlito_syrichta_NC_012774.1.gb
# Running analysis for Cebus_albifrons_NC_002763.1.gb
# Running analysis for Cephalopachus_bancanus_NC_002811.1.gb
# Running analysis for Cercocebus_atys_NC_028592.1.gb
# Running analysis for Cercocebus_chrysogaster_NC_021943.1.gb
# Running analysis for Cercocebus_torquatus_NC_023964.1.gb
# Running analysis for Cercopithecus_albogularis_NC_021944.1.gb
# Running analysis for Cercopithecus_diana_NC_023963.1.gb
# Running analysis for Cercopithecus_mitis_NC_023961.1.gb
# Running analysis for Cheirogaleus_crossleyi_NC_035604.1.gb
# Running analysis for Cheirogaleus_major_NC_035655.1.gb
# Running analysis for Cheirogaleus_medius_NC_021945.1.gb
# Running analysis for Cheirogaleus_sibreei_NC_035605.1.gb
# Running analysis for Cheracebus_lugens_NC_024630.1.gb
# Running analysis for Chiropotes_albinasus_NC_021946.1.gb
# Running analysis for Chiropotes_israelita_NC_024629.1.gb
# Running analysis for Chlorocebus_aethiops_NC_007009.1.gb
# Chlorocebus_aethiops_NC_007009.1.gb analysis failed
# Running analysis for Chlorocebus_aethiops_x_Chlorocebus_pygerythrus_NC_034276.1.gb
# Running analysis for Chlorocebus_cynosuros_NC_024933.1.gb
# Running analysis for Chlorocebus_djamdjamensis_NC_034277.1.gb
# Running analysis for Chlorocebus_pygerythrus_NC_009747.1.gb
# Running analysis for Chlorocebus_sabaeus_NC_008066.1.gb
# Chlorocebus_sabaeus_NC_008066.1.gb analysis failed
# Running analysis for Chlorocebus_tantalus_NC_009748.1.gb
# Running analysis for Colobus_guereza_NC_006901.1.gb
# Running analysis for Daubentonia_madagascariensis_NC_010299.1.gb
# Running analysis for Erythrocebus_patas_NC_021947.1.gb
# Running analysis for Eulemur_fulvus_fulvus_NC_012766.1.gb
# Running analysis for Eulemur_fulvus_mayottensis_NC_012769.1.gb
# Running analysis for Eulemur_macaco_macaco_NC_012771.1.gb
# Running analysis for Eulemur_mongoz_NC_010300.1.gb
# Running analysis for Eulemur_rubriventer_NC_026098.1.gb
# Eulemur_rubriventer_NC_026098.1.gb analysis failed
# Running analysis for Eulemur_rufus_NC_021948.1.gb
# Running analysis for Galago_moholi_NC_021949.1.gb
# Running analysis for Galago_senegalensis_NC_012761.1.gb
# Running analysis for Gorilla_beringei_NC_037853.1.gb
# Running analysis for Gorilla_gorilla_NC_001645.1.gb
# Running analysis for Gorilla_gorilla_gorilla_NC_011120.1.gb
# Running analysis for Hapalemur_griseus_NC_021950.1.gb
# Running analysis for Homo_heidelbergensis_NC_023100.1.gb
# Homo_heidelbergensis_NC_023100.1.gb analysis failed
# Running analysis for Homo_sapiens_NC_012920.1.gb
# Running analysis for Homo_sapiens_neanderthalensis_NC_011137.1.gb
# Running analysis for Homo_sapiens_subsp._Denisova_NC_013993.1.gb
# Running analysis for Hoolock_hoolock_NC_033885.1.gb
# Hoolock_hoolock_NC_033885.1.gb analysis failed
# Running analysis for Hoolock_leuconedys_NC_033882.1.gb
# Running analysis for Hoolock_leuconedys_x_Hoolock_tianxing_NC_033883.1.gb
# Running analysis for Hoolock_tianxing_NC_033884.1.gb
# Running analysis for Hylobates_agilis_NC_014042.1.gb
# Running analysis for Hylobates_lar_NC_002082.1.gb
# Running analysis for Hylobates_pileatus_NC_014045.1.gb
# Running analysis for Indri_indri_NC_026095.1.gb
# Running analysis for Lagothrix_lagotricha_NC_021951.1.gb
# Running analysis for Lemur_catta_NC_004025.1.gb
# Running analysis for Leontopithecus_chrysopygus_NC_037878.1.gb
# Running analysis for Leontopithecus_rosalia_NC_021952.1.gb
# Running analysis for Lepilemur_aeeclis_NC_034730.1.gb
# Running analysis for Lepilemur_ahmansonorum_NC_034733.1.gb
# Running analysis for Lepilemur_ankaranensis_NC_034717.1.gb
# Running analysis for Lepilemur_betsileo_NC_034726.1.gb
# Running analysis for Lepilemur_dorsalis_NC_034721.1.gb
# Running analysis for Lepilemur_edwardsi_NC_034720.1.gb
# Running analysis for Lepilemur_fleuretae_NC_034718.1.gb
# Running analysis for Lepilemur_grewcockorum_NC_034729.1.gb
# Running analysis for Lepilemur_hollandorum_NC_034738.1.gb
# Running analysis for Lepilemur_hubbardorum_NC_014453.1.gb
# Running analysis for Lepilemur_jamesorum_NC_034736.1.gb
# Running analysis for Lepilemur_leucopus_NC_034719.1.gb
# Running analysis for Lepilemur_microdon_NC_034739.1.gb
# Running analysis for Lepilemur_milanoii_NC_034725.1.gb
# Running analysis for Lepilemur_mittermeieri_NC_034728.1.gb
# Running analysis for Lepilemur_otto_NC_034724.1.gb
# Running analysis for Lepilemur_petteri_NC_034723.1.gb
# Running analysis for Lepilemur_randrianasoloi_NC_034722.1.gb
# Running analysis for Lepilemur_ruficaudatus_NC_021953.1.gb
# Running analysis for Lepilemur_sahamalazensis_NC_034734.1.gb
# Running analysis for Lepilemur_scottorum_NC_034737.1.gb
# Running analysis for Lepilemur_seali_NC_034731.1.gb
# Running analysis for Lepilemur_septentrionalis_NC_034727.1.gb
# Running analysis for Lepilemur_tymerlachsoni_NC_034735.1.gb
# Running analysis for Lepilemur_wrightae_NC_034732.1.gb
# Running analysis for Lophocebus_aterrimus_NC_021954.1.gb
# Running analysis for Loris_lydekkerianus_NC_021955.1.gb
# Running analysis for Loris_tardigradus_NC_012763.1.gb
# Running analysis for Macaca_arctoides_NC_025201.1.gb
# Running analysis for Macaca_assamensis_NC_023795.1.gb
# Running analysis for Macaca_cyclopis_NC_027449.1.gb
# Macaca_cyclopis_NC_027449.1.gb analysis failed
# Running analysis for Macaca_fascicularis_NC_012670.1.gb
# Running analysis for Macaca_fuscata_NC_025513.1.gb
# Running analysis for Macaca_leonina_NC_027604.1.gb
# Running analysis for Macaca_leucogenys_NC_031156.1.gb
# Running analysis for Macaca_mulatta_NC_005943.1.gb
# Running analysis for Macaca_mulatta_vestita_NC_037466.1.gb
# Running analysis for Macaca_nemestrina_NC_026976.1.gb
# Running analysis for Macaca_nigra_NC_026120.1.gb
# Running analysis for Macaca_radiata_NC_036508.1.gb
# Running analysis for Macaca_silenus_NC_025221.1.gb
# Running analysis for Macaca_sinica_NC_037437.1.gb
# Running analysis for Macaca_sylvanus_NC_002764.1.gb
# Running analysis for Macaca_thibetana_NC_011519.1.gb
# Running analysis for Macaca_tonkeana_NC_025222.1.gb
# Running analysis for Mandrillus_leucophaeus_NC_028442.1.gb
# Running analysis for Mandrillus_sphinx_NC_021956.1.gb
# Running analysis for Megaladapis_edwardsi_NC_026088.1.gb
# Megaladapis_edwardsi_NC_026088.1.gb analysis failed
# Running analysis for Microcebus_arnholdi_NC_035554.1.gb
# Running analysis for Microcebus_berthae_NC_035629.1.gb
# Running analysis for Microcebus_bongolavensis_NC_035559.1.gb
# Running analysis for Microcebus_danfossi_NC_035600.1.gb
# Running analysis for Microcebus_griseorufus_NC_035558.1.gb
# Running analysis for Microcebus_jollyae_NC_035564.1.gb
# Running analysis for Microcebus_lehilahytsara_NC_035602.1.gb
# Running analysis for Microcebus_mamiratra_NC_035601.1.gb
# Running analysis for Microcebus_margotmarshae_NC_035603.1.gb
# Running analysis for Microcebus_mittermeieri_NC_035563.1.gb
# Running analysis for Microcebus_murinus_NC_028718.1.gb
# Running analysis for Microcebus_myoxinus_NC_035557.1.gb
# Running analysis for Microcebus_ravelobensis_NC_035556.1.gb
# Running analysis for Microcebus_rufus_NC_035562.1.gb
# Microcebus_rufus_NC_035562.1.gb analysis failed
# Running analysis for Microcebus_sambiranensis_NC_035561.1.gb
# Running analysis for Microcebus_simmonsi_NC_035630.1.gb
# Running analysis for Microcebus_tanosi_NC_035555.1.gb
# Running analysis for Microcebus_tavaratra_NC_035560.1.gb
# Running analysis for Mirza_coquereli_NC_035656.1.gb
# Running analysis for Mirza_zaza_NC_035606.1.gb
# Running analysis for Nasalis_larvatus_NC_008216.1.gb
# Running analysis for Nomascus_gabriellae_NC_018753.1.gb
# Nomascus_gabriellae_NC_018753.1.gb analysis failed
# Running analysis for Nomascus_leucogenys_NC_021957.1.gb
# Running analysis for Nomascus_siki_NC_014051.1.gb
# Running analysis for Nycticebus_bengalensis_NC_021958.1.gb
# Running analysis for Nycticebus_coucang_NC_002765.1.gb
# Running analysis for Nycticebus_coucang_insularis_NC_040292.1.gb
# Running analysis for Nycticebus_pygmaeus_NC_033381.1.gb
# Running analysis for Otolemur_crassicaudatus_NC_012762.1.gb
# Running analysis for Palaeopropithecus_ingens_NC_026090.1.gb
# Running analysis for Pan_paniscus_NC_001644.1.gb
# Running analysis for Pan_troglodytes_NC_001643.1.gb
# Running analysis for Papio_anubis_NC_020006.2.gb
# Running analysis for Papio_cynocephalus_NC_020007.2.gb
# Running analysis for Papio_hamadryas_NC_001992.1.gb
# Running analysis for Papio_kindae_NC_020008.2.gb
# Running analysis for Papio_papio_NC_020009.2.gb
# Running analysis for Papio_ursinus_NC_020010.2.gb
# Running analysis for Perodicticus_potto_NC_012764.1.gb
# Running analysis for Phaner_electromontis_NC_035607.1.gb
# Running analysis for Phaner_pallescens_NC_035608.1.gb
# Running analysis for Phaner_parienti_NC_035609.1.gb
# Running analysis for Piliocolobus_badius_NC_008219.1.gb
# Running analysis for Plecturocebus_cupreus_NC_021965.1.gb
# Running analysis for Plecturocebus_donacophilus_NC_019801.1.gb
# Running analysis for Pongo_abelii_NC_002083.1.gb
# Running analysis for Pongo_pygmaeus_NC_001646.1.gb
# Running analysis for Presbytis_melalophos_NC_008217.1.gb
# Running analysis for Procolobus_verus_NC_020666.1.gb
# Procolobus_verus_NC_020666.1.gb analysis failed
# Running analysis for Prolemur_simus_NC_021959.1.gb
# Running analysis for Propithecus_coquereli_NC_011053.1.gb
# Running analysis for Propithecus_diadema_NC_026084.1.gb
# Running analysis for Propithecus_edwardsi_NC_026086.1.gb
# Running analysis for Propithecus_tattersalli_NC_027740.1.gb
# Running analysis for Propithecus_verreauxi_NC_028210.1.gb
# Running analysis for Pygathrix_cinerea_1_RL-2012_NC_018062.1.gb
# Running analysis for Pygathrix_cinerea_2_RL-2012_NC_018063.1.gb
# Running analysis for Pygathrix_nemaeus_NC_008220.1.gb
# Running analysis for Pygathrix_nigripes_NC_018061.1.gb
# Running analysis for Rhinopithecus_avunculus_NC_015485.1.gb
# Running analysis for Rhinopithecus_bieti_1_RL-2012_NC_018058.1.gb
# Running analysis for Rhinopithecus_bieti_2_RL-2012_NC_018060.1.gb
# Running analysis for Rhinopithecus_bieti_NC_015486.1.gb
# Running analysis for Rhinopithecus_brelichi_NC_018057.1.gb
# Running analysis for Rhinopithecus_roxellana_NC_008218.1.gb
# Running analysis for Rhinopithecus_strykeri_NC_018059.1.gb
# Running analysis for Saguinus_oedipus_NC_021960.1.gb
# Running analysis for Saimiri_boliviensis_NC_021966.1.gb
# Running analysis for Saimiri_boliviensis_boliviensis_NC_018096.1.gb
# Running analysis for Saimiri_oerstedii_citrinellus_NC_023211.1.gb
# Running analysis for Saimiri_sciureus_NC_012775.1.gb
# Running analysis for Sapajus_xanthosternos_NC_021961.1.gb
# Running analysis for Semnopithecus_entellus_NC_008215.1.gb
# Running analysis for Simias_concolor_NC_020667.1.gb
# Running analysis for Symphalangus_syndactylus_NC_014047.1.gb
# Running analysis for Tarsius_dentatus_NC_024052.1.gb
# Running analysis for Tarsius_lariang_NC_024051.1.gb
# Running analysis for Tarsius_wallacei_NC_024053.1.gb
# Running analysis for Theropithecus_gelada_NC_019802.1.gb
# Running analysis for Trachypithecus_cristatus_NC_023971.1.gb
# Running analysis for Trachypithecus_francoisi_NC_023970.1.gb
# Running analysis for Trachypithecus_germaini_NC_019580.1.gb
# Running analysis for Trachypithecus_hatinhensis_NC_019579.1.gb
# Running analysis for Trachypithecus_johnii_NC_019583.1.gb
# Running analysis for Trachypithecus_obscurus_NC_006900.1.gb
# Running analysis for Trachypithecus_pileatus_NC_024529.1.gb
# Running analysis for Trachypithecus_poliocephalus_NC_034795.1.gb
# Running analysis for Trachypithecus_shortridgei_NC_019581.1.gb
# Running analysis for Trachypithecus_vetulus_NC_019582.1.gb
# Running analysis for Varecia_variegata_NC_026085.1.gb
# Varecia_variegata_NC_026085.1.gb analysis failed
# Running analysis for Varecia_variegata_variegata_NC_012773.1.gb
#                         Species  Translation Table Aminoacid Codon Anticodon  \
# 0   Allenopithecus_nigroviridis                  2       Phe   TTT      None
# 1   Allenopithecus_nigroviridis                  2       Phe   TTC       GAA
# 2   Allenopithecus_nigroviridis                  2       Leu   TTA       TAA
# 3   Allenopithecus_nigroviridis                  2       Leu   TTG      None
# 4   Allenopithecus_nigroviridis                  2       Leu   CTT      None
# 5   Allenopithecus_nigroviridis                  2       Leu   CTC      None
# 6   Allenopithecus_nigroviridis                  2       Leu   CTA       TAG
# 7   Allenopithecus_nigroviridis                  2       Leu   CTG      None
# 8   Allenopithecus_nigroviridis                  2       Ser   TCT      None
# 9   Allenopithecus_nigroviridis                  2       Ser   TCC      None
# 10  Allenopithecus_nigroviridis                  2       Ser   TCA       TGA
# 11  Allenopithecus_nigroviridis                  2       Ser   TCG      None
# 12  Allenopithecus_nigroviridis                  2       Ser   AGT      None
# 13  Allenopithecus_nigroviridis                  2       Ser   AGC       GCT
# 14  Allenopithecus_nigroviridis                  2       Tyr   TAT      None
# 15  Allenopithecus_nigroviridis                  2       Tyr   TAC       GTA
# 16  Allenopithecus_nigroviridis                  2       Cys   TGT      None
# 17  Allenopithecus_nigroviridis                  2       Cys   TGC       GCA
# 18  Allenopithecus_nigroviridis                  2       Trp   TGA       TCA
# 19  Allenopithecus_nigroviridis                  2       Trp   TGG      None
# 20  Allenopithecus_nigroviridis                  2       Pro   CCT      None
# 21  Allenopithecus_nigroviridis                  2       Pro   CCC      None
# 22  Allenopithecus_nigroviridis                  2       Pro   CCA       TGG
# 23  Allenopithecus_nigroviridis                  2       Pro   CCG      None
# 24  Allenopithecus_nigroviridis                  2       His   CAT      None
# 25  Allenopithecus_nigroviridis                  2       His   CAC       GTG
# 26  Allenopithecus_nigroviridis                  2       Gln   CAA       TTG
# 27  Allenopithecus_nigroviridis                  2       Gln   CAG      None
# 28  Allenopithecus_nigroviridis                  2       Arg   CGT      None
# 29  Allenopithecus_nigroviridis                  2       Arg   CGC      None
# ..                          ...                ...       ...   ...       ...
# 34  Varecia_variegata_variegata                  2       Met   ATA      None
# 35  Varecia_variegata_variegata                  2       Met   ATG       CAT
# 36  Varecia_variegata_variegata                  2       Thr   ACT      None
# 37  Varecia_variegata_variegata                  2       Thr   ACC      None
# 38  Varecia_variegata_variegata                  2       Thr   ACA       TGT
# 39  Varecia_variegata_variegata                  2       Thr   ACG      None
# 40  Varecia_variegata_variegata                  2       Asn   AAT      None
# 41  Varecia_variegata_variegata                  2       Asn   AAC       GTT
# 42  Varecia_variegata_variegata                  2       Lys   AAA       TTT
# 43  Varecia_variegata_variegata                  2       Lys   AAG      None
# 44  Varecia_variegata_variegata                  2       Val   GTT      None
# 45  Varecia_variegata_variegata                  2       Val   GTC      None
# 46  Varecia_variegata_variegata                  2       Val   GTA       TAC
# 47  Varecia_variegata_variegata                  2       Val   GTG      None
# 48  Varecia_variegata_variegata                  2       Ala   GCT      None
# 49  Varecia_variegata_variegata                  2       Ala   GCC      None
# 50  Varecia_variegata_variegata                  2       Ala   GCA       TGC
# 51  Varecia_variegata_variegata                  2       Ala   GCG      None
# 52  Varecia_variegata_variegata                  2       Asp   GAT      None
# 53  Varecia_variegata_variegata                  2       Asp   GAC       GTC
# 54  Varecia_variegata_variegata                  2       Glu   GAA       TTC
# 55  Varecia_variegata_variegata                  2       Glu   GAG      None
# 56  Varecia_variegata_variegata                  2       Gly   GGT      None
# 57  Varecia_variegata_variegata                  2       Gly   GGC      None
# 58  Varecia_variegata_variegata                  2       Gly   GGA       TCC
# 59  Varecia_variegata_variegata                  2       Gly   GGG      None
# 60  Varecia_variegata_variegata                  2       End   TAA      None
# 61  Varecia_variegata_variegata                  2       End   TAG      None
# 62  Varecia_variegata_variegata                  2       End   AGA      None
# 63  Varecia_variegata_variegata                  2       End   AGG      None
#
#     Number of Codon Occurences  /1000  Fraction
# 0                           99  25.98      0.45
# 1                          120  31.50      0.55
# 2                          102  26.77      0.16
# 3                           17   4.46      0.03
# 4                           97  25.46      0.15
# 5                          103  27.03      0.16
# 6                          282  74.02      0.45
# 7                           26   6.82      0.04
# 8                           53  13.91      0.19
# 9                           81  21.26      0.29
# 10                          78  20.47      0.28
# 11                           9   2.36      0.03
# 12                          18   4.72      0.06
# 13                          39  10.24      0.14
# 14                          53  13.91      0.40
# 15                          81  21.26      0.60
# 16                           9   2.36      0.38
# 17                          15   3.94      0.62
# 18                          93  24.41      0.91
# 19                           9   2.36      0.09
# 20                          45  11.81      0.22
# 21                          82  21.52      0.40
# 22                          76  19.95      0.37
# 23                           4   1.05      0.02
# 24                          33   8.66      0.34
# 25                          65  17.06      0.66
# 26                          93  24.41      0.95
# 27                           5   1.31      0.05
# 28                          11   2.89      0.17
# 29                          21   5.51      0.32
# ..                         ...    ...       ...
# 34                         231  60.81      0.90
# 35                          26   6.84      0.10
# 36                          68  17.90      0.22
# 37                          97  25.53      0.32
# 38                         134  35.27      0.44
# 39                           7   1.84      0.02
# 40                          71  18.69      0.44
# 41                          92  24.22      0.56
# 42                          90  23.69      0.93
# 43                           7   1.84      0.07
# 44                          42  11.06      0.25
# 45                          33   8.69      0.20
# 46                          81  21.32      0.49
# 47                          11   2.90      0.07
# 48                          59  15.53      0.25
# 49                          94  24.74      0.40
# 50                          80  21.06      0.34
# 51                           1   0.26      0.00
# 52                          34   8.95      0.54
# 53                          29   7.63      0.46
# 54                          82  21.58      0.85
# 55                          14   3.69      0.15
# 56                          54  14.21      0.26
# 57                          55  14.48      0.26
# 58                          73  19.22      0.35
# 59                          29   7.63      0.14
# 60                           8   2.11      0.62
# 61                           3   0.79      0.23
# 62                           1   0.26      0.08
# 63                           1   0.26      0.08
#
# [12736 rows x 8 columns]

# %% [markdown]
# ## Just me messing around with codon tables and such

# %%
codon_tables = set_ncbi_genetic_codes()

print(codon_tables[2])
# Out:
# {'Phe': ['TTT', 'TTC'], 'Leu': ['TTA', 'TTG', 'CTT', 'CTC', 'CTA', 'CTG'], 'Ser': ['TCT', 'TCC', 'TCA', 'TCG', 'AGT', 'AGC'], 'Tyr': ['TAT', 'TAC'], 'Cys': ['TGT', 'TGC'], 'Trp': ['TGA', 'TGG'], 'Pro': ['CCT', 'CCC', 'CCA', 'CCG'], 'His': ['CAT', 'CAC'], 'Gln': ['CAA', 'CAG'], 'Arg': ['CGT', 'CGC', 'CGA', 'CGG'], 'Ile': ['ATT', 'ATC'], 'Met': ['ATA', 'ATG'], 'Thr': ['ACT', 'ACC', 'ACA', 'ACG'], 'Asn': ['AAT', 'AAC'], 'Lys': ['AAA', 'AAG'], 'Val': ['GTT', 'GTC', 'GTA', 'GTG'], 'Ala': ['GCT', 'GCC', 'GCA', 'GCG'], 'Asp': ['GAT', 'GAC'], 'Glu': ['GAA', 'GAG'], 'Gly': ['GGT', 'GGC', 'GGA', 'GGG'], 'End': ['TAA', 'TAG', 'AGA', 'AGG']}

# %%
print(genbank[2])
# Out:
# Allochrocebus_lhoesti_NC_023962.1.gb

# %%
fields = ['species', 'transl_table', 'aminoacid', "Anticodon", 
                  'Number of codon occurences', '/1000', 'Fraction']
excel_output_dict = {k : list() for k in fields}

# %%
for key, value in fraction_dict.items():
    print(key, value)
# Out:
# TTT 0.45
# TTC 0.55
# TTA 0.16
# TTG 0.03
# CTT 0.15
# CTC 0.16
# CTA 0.45
# CTG 0.04
# TCT 0.19
# TCC 0.29
# TCA 0.28
# TCG 0.03
# AGT 0.06
# AGC 0.14
# TAT 0.4
# TAC 0.6
# TGT 0.38
# TGC 0.62
# TGA 0.91
# TGG 0.09
# CCT 0.22
# CCC 0.4
# CCA 0.37
# CCG 0.02
# CAT 0.34
# CAC 0.66
# CAA 0.95
# CAG 0.05
# CGT 0.17
# CGC 0.32
# CGA 0.45
# CGG 0.06
# ATT 0.46
# ATC 0.54
# ATA 0.85
# ATG 0.15
# ACT 0.21
# ACC 0.33
# ACA 0.44
# ACG 0.02
# AAT 0.33
# AAC 0.67
# AAA 0.93
# AAG 0.07
# GTT 0.23
# GTC 0.29
# GTA 0.4
# GTG 0.08
# GCT 0.26
# GCC 0.43
# GCA 0.3
# GCG 0.01
# GAT 0.45
# GAC 0.55
# GAA 0.79
# GAG 0.21
# GGT 0.22
# GGC 0.34
# GGA 0.32
# GGG 0.12
# TAA 0.85
# TAG 0.08
# AGA 0.0
# AGG 0.08

# %%
ls = list()

# %%
ls.append(None)

# %%
ls
# Out:
# [None]

# %%
amino_acid = seq3("F")

# %%
amino_acid
# Out:
# 'Phe'
